# %% [markdown]
# ### Langchain version v1

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

os.environ["OPENAI_API_KEY"] = os.getenv("OPENAI_API_KEY")

# %%
from langcahin.agents import create_agent


agent = create_agent(
    model = "gpt-5",
    tools = [],
    system_prompt = "You are a helpful assistant.",
    verbose = True
)
agent
